# %% [markdown]
# # Loop Inference with Camera and Threads
#
# Loop is run with 4 threads and images are plotted inside asyncio loop:
#
# 1. ```get_frames```:
#     - Retrieve images from the camera at the desired fps.
#     - It warms up the camera taking a few images first, controlled by ```WARM_UP_FRAMES```.
#     - It blocks until warm up frames are plotted.
# 2. ```do_batches```:
#     - Takes images from get_frames and create batches for the accelerator.
#     - It also sends images to plot.
# 3. ```accel_exec```:
#     - Asynchronous execution of the accelerator.
# 4. ```check_dma_ready```:
#     - Polls the DMA to check if accelerator has finished the batch prediction.
#
# - ```plot_frames```:
#     - asyncio function to plot frames.
#     - It plots all warm up frames.
#     - It plots a portion of images inside the batch.
#     - It computes the mean of the batch prediction, an uses it as a final prediction for the whole batch.

# %%
import os
import numpy as np

from threading import Thread, Event
from queue import Queue
import asyncio

import cv2
import opencv_jupyter_ui as jcv2

from datetime import datetime, timedelta
import time

import driver
from pynq.pl_server.device import Device

# %% [markdown]
# # Config

# %%
FRAME_IN_W = 640        # Image width to capture by camera
FRAME_IN_H = 480        # Image height to capture by camera
N_FRAMES = 8000         # Number of images to predict

IMG_W_RSZ = 224         # Image width resize for the accelerator
IMG_H_RSZ = 224         # Image height resize for the accelerator
BATCH_SIZE = 20         # Be careful if Camera does not provide xxx FPS, as time computation may be wrong
FPGA_CLK = 4.0          # FPGA clock

CAP_FPS = BATCH_SIZE    # fps to capture

WARM_UP_FRAMES = 5
NUM_FRAMES_TO_PLOT = 3  # Plot 2 images of every batch

VERBOSE = False
# Sleep if there are no new frames from the camera
SLEEP_BATCH_FRAME = 0.01
# Sleep DMA while inference is calculated: used for polling DMA
SLEEP_DMA_POLL = 0.2

# %% [markdown]
# # Accelerator
#
# There are two new functions in the accelerator, to run asynchronously and poll the DMA for the result. This could be done with interruptions too, adding them to Vivado Block Design.
#
# ```python
# def async_exec(self, input_npy)
# def polling_out_dma_ready(self)
# ```

# %%
my_device = Device.devices[0]

accel = driver.FINNExampleOverlay(
    bitfile_name = '../bitfile/finn-accel.bit', 
    platform = "zynq-iodma",
    io_shape_dict = driver.io_shape_dict, 
    batch_size = BATCH_SIZE,
    fclk_mhz = FPGA_CLK,
    runtime_weight_dir = "runtime_weights/", 
    device=my_device
)
# Out:
# Asynch = False -> block until finished

# %% [markdown]
# ### Initial Throughput Test

# %%
res = accel.throughput_test()
file = open("nw_metrics_threads.txt", "w")
file.write(str(res))
file.close()
print("Results written to nw_metrics.txt")
# Out:
# Asynch = False -> block until finished
# Results written to nw_metrics.txt

# %% [markdown]
# # Camera Setup

# %%
def init_videocapture(width=1280, height=720, fps = 30):
    camera = cv2.VideoCapture(0, cv2.CAP_V4L2)
    camera.set(cv2.CAP_PROP_FRAME_WIDTH, width)
    camera.set(cv2.CAP_PROP_FRAME_HEIGHT, height)
    camera.set(cv2.CAP_PROP_FOURCC, cv2.VideoWriter_fourcc('M', 'J', 'P', 'G'))
    camera.set(cv2.CAP_PROP_FPS, fps)
    return camera

# %% [markdown]
# # Camera Thread

# %%
def get_frames(
    event_warm_up_ready,
    event_initial_plot_ready,
    queue_warm_up,
    queue_frames,
    frame_in_w, 
    frame_in_h, 
    n_frames,
    batch_size,
    warm_up_frames = 5,
    cap_fps = 30,
    verbose = False):
    
    '''
    Get frames continuously from the camera.
    '''
    
    capture = init_videocapture(width=frame_in_w, height=frame_in_h, fps=cap_fps)
    print(f'$ Camera Thread: Is webcam open: {capture.isOpened()}')
    img_w = capture.get(cv2.CAP_PROP_FRAME_WIDTH)
    img_h = capture.get(cv2.CAP_PROP_FRAME_HEIGHT)
    cv_fps = capture.get(cv2.CAP_PROP_FPS) 
    print(f'$ Camera Thread: Camera (width, height) = ({img_w}, {img_h}) - FPS = {cv_fps}')
    
    ################################
    #           Warm Up            #
    ################################
    warm_up_count = 0
    while (warm_up_count < warm_up_frames):
        ret, frame = capture.read()
        queue_warm_up.put(frame)
        warm_up_count += 1
    event_warm_up_ready.set()
    print(f'\n$ Camera Thread: Warm up of {warm_up_frames} frames finished\n')
    print(f'\n$ Camera Thread: Waiting for Initial Plot\n')
    event_initial_plot_ready.wait()
    print(f'\n$ Camera Thread: Initial Plot finished\n')
    
    ################################
    #            Loop              #
    ################################
    img_count = 0
    start = datetime.now()
    while (img_count < n_frames):
        ret, frame = capture.read()
        queue_frames.put(frame)
        if verbose == True:
            img_in_batch = img_count % batch_size
            print(f'$ Camera Thread: got image = {img_count} - Id in batch: {img_in_batch} - Queue frames size = {queue_frames.qsize()}.')
        img_count += 1
    end = datetime.now()
    
    queue_frames.put(None) # Signal plot_frames to stop
    
    delta_secs = (end-start).total_seconds()
    fps = round(n_frames / delta_secs, 1)
    print("\n$ *******************************")
    print(f'$ Camera Thread: FPS = {fps:.1f}')
    print("$ *******************************\n")
    
    capture.release()

# %% [markdown]
# # Batches Thread
#
# Fills the Queue to plot ```NUM_FRAMES_TO_PLOT``` images per inference. It computes the interval based in ```BATCH_SIZE```.
#
# Example:
# - Batch of 20 images.
# - ```NUM_FRAMES_TO_PLOT = 3```
#
# $$
# Interval = \lceil \frac{Batch}{Plot_{Frames}} \rceil = \lceil \frac{20}{3} \rceil = 7
# $$
#
# Therefore, it will plot image index 0, 7 and 14.

# %%
def do_batches(
    queue_frames, 
    queue_batches, 
    event_batch_ready, 
    batch_size,
    queue_frames_2_plot,
    num_frames_2_plot,
    sleep_time = 0.02,
    verbose = False): #, queue_frames_2_plot):
    
    '''
    Do batches taking images from Queue Frames. Sleep if there are no frames in the queue.
        - BGR2RGB
        - Resize
        - Expand dims to add batch dim
    Once a batch is formed, put it in Queue Batches.
    Queue Batches is of size 1, to block if previous batch was not predicted by the accelerator.
    
    Put num_frames_2_plot images of the batch in the queue_frames_2_plot, to plot it afterwards.
    '''
    
    batch_idx = 0
    img_id = 0
    assert num_frames_2_plot <= batch_size, f'Please, {num_frames_2_plot} <= {batch_size}'
    img_2_plot_interval = int(batch_size / num_frames_2_plot) + 1
    frames_2_plot_list = []
    
    while True:
        if queue_frames.empty():
            if verbose == True:
                print(">> Batches Thread: empty queue frames from camera")
            time.sleep(sleep_time)
        else:
            frame = queue_frames.get()
            if verbose == True:
                print(f">> Batches Thread: image {img_id} for batch {batch_idx} - Queue batches size = {queue_batches.qsize()}.")
            if frame is None:
                break 
            # Form batches for accel prediction
            img = frame.copy()
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, (IMG_W_RSZ, IMG_H_RSZ), interpolation = cv2.INTER_LINEAR)
            assert img.dtype == "uint8", "Image datatype must be UINT8"
            img = np.expand_dims(img, axis=0)
            if img_id == 0:
                # To plot images inside notebook
                frames_2_plot_list.append(frame)
                if verbose == True:
                    print(f">> Batches Thread: plot frame added to batch {batch_idx} - Queue plot size = {queue_frames_2_plot.qsize()}.")
                batch_imgs = img
            else:
                batch_imgs = np.concatenate((batch_imgs, img), axis=0)
                if img_id % img_2_plot_interval == 0:
                    frames_2_plot_list.append(frame)
            if img_id == (batch_size - 1):
                # Put blocks if accel did not get previous batch
                queue_batches.put([batch_idx, batch_imgs])
                # Put list of frames to plot
                print(f">> Batches Thread: sending {len(frames_2_plot_list)} to plot.")
                queue_frames_2_plot.put([batch_idx, frames_2_plot_list])
                if verbose == True:
                    print(f">> Batches Thread: Batch {batch_idx} for accel - Queue batches size = {queue_batches.qsize()}.")
                event_batch_ready.set()
                batch_idx += 1
                # Empty list of frames 2 plot, to use with next batch
                frames_2_plot_list = []
            img_id = (img_id + 1) % batch_size
            queue_frames.task_done()
    
    # Signal queues to stop
    print(">> Batches Thread: No more batches to do. Put None.")
    queue_batches.put([batch_idx, None])
    queue_frames_2_plot.put([batch_idx, None])
    time.sleep(5)
    event_batch_ready.set()

# %% [markdown]
# # Accel Thread

# %%
def accel_exec(
    queue_batches, 
    event_batch_ready, 
    event_accel_exec, 
    event_yhat_ready_accel,
    verbose = False):
    
    '''
    Asynchronous execution of the accelerator.
    It waits for a batch ready.
    It blocks until previous prediction is retrieved by the DMA.
    '''
    
    batch_idx = 0
    
    while True:
        event_batch_ready.wait()
        event_batch_ready.clear()
        # It avoids getting the new batch if previous one was not retrieved from DMA first
        # Therefore, this thread blocks until previous inference is performed
        # It causes that do_batches and get_frames gets blocked too
        event_yhat_ready_accel.wait()
        event_yhat_ready_accel.clear()
        do_batch_idx, batch = queue_batches.get()
        assert do_batch_idx == batch_idx, f"@ Accel Thread: do batch idx {do_batch_idx} does not match accel batch idx {batch_idx}."
        if batch is None:
            print("@@@ Accel Thread: No more Batches signal received.")
            break
        if verbose == True:
            print(f'@@@ Accel Thread: Batch idx {batch_idx}. Batch shape = {batch.shape}.')
        # Execute accelerator
        if verbose == True:
            start_accel = datetime.now()
        accel.async_exec([batch])
        # Notify DMA Poll that it can start polling for prediction ready
        if verbose == True:
            end_accel = datetime.now()
            print(f'@@@ Accel Thread: time to exec accel {(end_accel-start_accel).microseconds/1e3:.2f} [ms] - {end_accel}')   
        event_accel_exec.set()
        batch_idx += 1  
        queue_batches.task_done()
        
    queue_batches.task_done()

# %% [markdown]
# # Check DMA Result Thread

# %%
def check_dma_ready(
    event_accel_exec, 
    queue_yhat, 
    event_yhat_ready,
    event_yhat_ready_accel,
    n_frames, 
    batch_size,
    sleep_time = 0.01,
    verbose = False):
    
    '''
    Polls the DMA to check if prediction was already completed by the accelerator.
    It signals the accelerator that prediction was completed, so it can load next batch: event_yhat_ready_accel.
    It signals the main thread that prediction is ready, so it can plot it: event_yhat_ready. 
    
    With this strategy, it blocks do_batches, as the accelerator cannot accept new batches until previous one is completed.
    '''
    
    total_batches = int(n_frames / batch_size)
    batch_idx = 0
    
    accel_preds_times = []
    
    while (batch_idx < total_batches):
        event_accel_exec.wait()
        start_accel = datetime.now()           
        event_accel_exec.clear()
        if verbose == True:
            print(f"**** DMA Thread: Accel started Execution - {start_accel}.")
        while True:
            if verbose == True:
                now_time = datetime.now()   
                print(f"**** DMA Thread: ... Polling for DMA result ... : {now_time}")
            out_ready, yhat = accel.polling_out_dma_ready()
            if out_ready == True:
                queue_yhat.put([batch_idx, yhat])
                
                if verbose == True:
                    print("\nOutput DMA ready")
                    print(f'{yhat}')
                    # Calculate time between predictions
                    end_accel = datetime.now()
                    if batch_idx == 0:
                        accel_preds_times.append(end_accel)
                    else:
                        accel_preds_times.append(end_accel)
                        time_between_preds = accel_preds_times[1] - accel_preds_times[0]
                        if batch_idx == 1:
                            accel_preds_sum = time_between_preds
                        else:
                            accel_preds_sum = accel_preds_sum + time_between_preds
                        accel_preds_mean_time = accel_preds_sum / batch_idx
                        accel_preds_times.pop(0)
                        print(f'\n_____ Accel between predictions: {time_between_preds.total_seconds():.2f} [secs] _____')
                        print(f'_____ Mean Accel between predictions: {accel_preds_mean_time.total_seconds():.2f} [secs] _____')
                    print(f'_____ Accel elapsed time: {(end_accel-start_accel).microseconds/1e3:.2f} [ms] _____\n')   
                
                # Print time between predictions and accel elapsed time close to plot window
                else:
                    end_accel = datetime.now()
                    if batch_idx == 0:
                        accel_preds_times.append(end_accel)
                        str_2_print = ""
                    else:
                        accel_preds_times.append(end_accel)
                        time_between_preds = accel_preds_times[1] - accel_preds_times[0]
                        if batch_idx == 1:
                            accel_preds_sum = time_between_preds
                        else:
                            accel_preds_sum = accel_preds_sum + time_between_preds
                        accel_preds_mean_time = accel_preds_sum / batch_idx
                        accel_preds_times.pop(0)
                        str_2_print = f'\nBatch idx = {batch_idx}\n'
                        str_2_print += f'--- Accel between predictions: {time_between_preds.total_seconds():.2f} [secs]\n'
                        str_2_print += f'*** Mean Accel between predictions: {accel_preds_mean_time.total_seconds():.2f} [secs]\n'
                    str_2_print += f'... Accel elapsed time: {(end_accel-start_accel).microseconds/1e3:.2f} [ms]\n'
                    print(str_2_print, end='\r')
                
                event_yhat_ready.set()
                # Finish blocking of accel if needed
                event_yhat_ready_accel.set()
                batch_idx += 1
                break
            else:
                if verbose == True:
                    print(f"**** DMA Thread: yhat not ready. Sleep {sleep_time} [secs].")
                time.sleep(sleep_time)
            
    # Signal queues to stop
    print("**** DMA Thread: No more batches to do. Put None.")
    queue_yhat.put([batch_idx, None])
    time.sleep(5)
    event_yhat_ready.set()

# %% [markdown]
# # Plot Thread

# %% [markdown]
# #### Colors

# %%
GRAY_COLOR = (50, 50, 50)      # No Smoke, No Fire
RED_COLOR = (0,0,255)          # Only Fire
BLUE_COLOR = (255,255,0)       # Only Smoke
YELLOW_COLOR = (0,255,255)     # Smoke & Fire

# %% [markdown]
# #### Draw Prediction in Frame Function

# %%
def draw_pred_box(yhat, img_to_plot, img_w, img_h):

    yhat_str = np.array2string(yhat)
    empty_str = "Empty: " + yhat_str
    smoke_str = "Smoke: " + yhat_str
    fire_str = "Fire: " + yhat_str
    smoke_fire_str = "Smoke & Fire: " + yhat_str

    # Empty
    if yhat[0] < 0.5 and yhat[1] < 0.5:
        cv2.rectangle(img_to_plot, (0,0), (img_w, img_h), GRAY_COLOR, 20)
        cv2.rectangle(img_to_plot, (0,0), (img_w, 35), GRAY_COLOR, -1)
        cv2.putText(img_to_plot, empty_str, (8, 25), cv2.FONT_HERSHEY_SIMPLEX, 1, WHITE_COLOR, 1) 
    # Smoke
    elif yhat[0] > 0.5 and yhat[1] < 0.5:
        cv2.rectangle(img_to_plot, (0,0), (img_w, img_h), BLUE_COLOR, 20)
        cv2.rectangle(img_to_plot, (0,0), (img_w, 35), BLUE_COLOR, -1)
        cv2.putText(img_to_plot, smoke_str, (8, 25), cv2.FONT_HERSHEY_SIMPLEX, 1, BLACK_COLOR, 1) 
    # Fire
    elif yhat[0] < 0.5 and yhat[1] > 0.5:
        cv2.rectangle(img_to_plot, (0,0), (img_w, img_h), RED_COLOR, 20)
        cv2.rectangle(img_to_plot, (0,0), (img_w, 35), RED_COLOR, -1)
        cv2.putText(img_to_plot, fire_str, (8, 25), cv2.FONT_HERSHEY_SIMPLEX, 1, BLACK_COLOR, 1) 
    # Smoke & Fire
    elif yhat[0] > 0.5 and yhat[1] > 0.5:
        cv2.rectangle(img_to_plot, (0,0), (img_w, img_h), YELLOW_COLOR, 20)
        cv2.rectangle(img_to_plot, (0,0), (img_w, 35), YELLOW_COLOR, -1)
        cv2.putText(img_to_plot, smoke_fire_str, (8, 25), cv2.FONT_HERSHEY_SIMPLEX, 1, BLACK_COLOR, 1)
        
    return img_to_plot

# %% [markdown]
# #### Plot several frames per inference
#
# The number of frames can be defined in do_batches

# %%
async def plot_frames(
    event_warm_up_ready,
    event_initial_plot_ready,
    queue_warm_up,
    event_yhat_ready,
    queue_yhat,
    queue_frames_2_plot):
    
    '''
    It waits the warm up signal and plot 1 frame.
    Once a prediction is ready, it computes the mean and plot the images with color boxes.
    '''

    ################################
    #           Warm Up            #
    ################################
    event_warm_up_ready.wait()
    print(':):):) Plot Thread: start Initial Plot.')    
    for i in range(queue_warm_up.qsize()):
        new_frame = queue_warm_up.get()
        if i == 0:
            jcv2.imshow('UAV', new_frame)
        queue_warm_up.task_done()
    event_initial_plot_ready.set()
    
    ################################
    #            Loop              #
    ################################
    plot_batch_idx = 0

    while True:
        event_yhat_ready.wait()
        event_yhat_ready.clear()
        yhat_batch_idx, yhat = queue_yhat.get()
        plot_frames_idx, frames_to_plot_list = queue_frames_2_plot.get()
        assert yhat_batch_idx == plot_batch_idx, f':) Plot Thread: plot batch idx {plot_batch_idx} does not match yhat batch idx {yhat_batch_idx}.'
        assert plot_frames_idx == plot_batch_idx, f':) Plot Thread: plot frames idx {plot_frames_idx} does not match batch idx {yhat_batch_idx}.'
        if yhat is None:
            print(':):):) Plot Thread: yhat is None received -> Execution Finished')
            break
        else:
            yhat_mean = np.mean(yhat, axis=0)
            smoke_mean = yhat_mean[0]
            fire_mean = yhat_mean[1]
            if VERBOSE:
                print(f':):):) Plot Thread: yhat\n {yhat}')
                print(f':):):) Plot Thread: smoke mean = {smoke_mean}')
                print(f':):):) Plot Thread: fire mean = {fire_mean}')
                print(f':):):) Plot Thread: frames to plot list length = {len(frames_to_plot_list)} \n')
            for frame in frames_to_plot_list:
                frame_to_plot = draw_pred_box(yhat_mean, frame, FRAME_IN_W, FRAME_IN_H)   
                jcv2.imshow('UAV', frame_to_plot)
                if jcv2.waitKey(1)==ord('q'):
                    break 
                time.sleep(0.3)
            plot_batch_idx += 1
            queue_yhat.task_done()
            queue_frames_2_plot.task_done()

    queue_yhat.task_done()
    queue_frames_2_plot.task_done()
    jcv2.destroyAllWindows()

# %% [markdown]
# # Threads Communication: Queues and Events
#
# ### Queues
# - ```queue_warm_up```:
#     - get_frames fills it for plot_frames.
# - ```queue_frames```:
#     - get_frames fills it and do_batches consumes it.
# - ```queue_batches```
#     - do_batches  fills it and accel_exec consumes it.
#     - size = 1, so it blocks do_batches if accel_exec did not predict the previous batch yet.
# - ```queue_yhat```:
#     - check_dma_ready fills it and plot_frames consumes it.
#     - size = 1, so it blocks check_dma_ready if accel_exec did not predict the previous batch yet.
# - ```queue_frames_2_plot```:
#     - do_batches fills it and plot_frames consumes it.
#
# ### Events
# - ```event_warm_up_ready```:
#     - get_frames notifies that warm up is finished, so plot_frames can plot the images.
# - ```event_initial_plot_ready```:
#     - plot_frames notifies that warm up is finished, so get_frames can retrieve images for the accelerator.
# - ```event_batch_ready```:
#     - do_batches notifies that new batch is ready for the accelerator.
# - ```event_accel_exec```:
#     - accel_exec notifies that it is starting the prediction of a new batch.
#     - It triggers check_dma_ready, so it starts polling for the prediction.
# - ```event_yhat_ready_accel```:
#     - check_dma_ready notifies that prediction is ready, so the accelerator is free for new batches.
#     - It is initialized = 1, as the accelerator starts available.
# - ```event_yhat_ready```:
#     - check_dma_ready notifies that prediction is ready, so plot_frames can plot the prediction.

# %% [markdown]
# ### Setup Queues

# %%
queue_warm_up = Queue(maxsize=WARM_UP_FRAMES)

queue_frames = Queue(maxsize=BATCH_SIZE*2) # -> BATCH_SIZE*2 is very conservative, it should be reduced
queue_batches = Queue(maxsize=1)
queue_yhat = Queue(maxsize=1)
queue_frames_2_plot = Queue(maxsize=8)

# %% [markdown]
# ### Setup Events

# %%
event_warm_up_ready = Event()
event_initial_plot_ready = Event()

event_batch_ready = Event()
event_accel_exec = Event()
event_yhat_ready_accel = Event()
event_yhat_ready_accel.set() # To let first batch start in the accelerator
event_yhat_ready = Event()

# %% [markdown]
# ### Setup Threads

# %%
cap_thread = Thread(
    target=get_frames, 
    args=(
        event_warm_up_ready, event_initial_plot_ready, queue_warm_up,
        queue_frames, FRAME_IN_W, FRAME_IN_H, N_FRAMES, BATCH_SIZE, WARM_UP_FRAMES, CAP_FPS, VERBOSE,))

batches_thread = Thread(
    target=do_batches, 
    args=(queue_frames, queue_batches, event_batch_ready, BATCH_SIZE, 
          queue_frames_2_plot, 
          NUM_FRAMES_TO_PLOT,
          SLEEP_BATCH_FRAME, VERBOSE,))

accel_thread = Thread(
    target=accel_exec, 
    args=(queue_batches, event_batch_ready, event_accel_exec, event_yhat_ready_accel, VERBOSE,))

check_dma_ready = Thread(
    target=check_dma_ready, 
    args=(event_accel_exec, queue_yhat, event_yhat_ready, event_yhat_ready_accel, N_FRAMES, BATCH_SIZE, SLEEP_DMA_POLL, VERBOSE,))

# %% [markdown]
# ### Asyncio Thread to Plot

# %%
def run_event_loop(loop):
    # report a message
    print('Asyncio event loop is running')
    # set the loop for the current thread
    asyncio.set_event_loop(loop)
    # run the event loop until stopped
    loop.run_forever()
    
# create a new event loop (low-level api)
loop = asyncio.new_event_loop()

plot_thread = Thread(target=run_event_loop, args=(loop,), daemon=True)

# %% [markdown]
# ### Start Threads

# %%
start_running = datetime.now()

# %%
cap_thread.start()
batches_thread.start()
accel_thread.start()
check_dma_ready.start()

# %%
plot_thread.start()
print("\nWaiting for capture thread")

future = asyncio.run_coroutine_threadsafe(plot_frames(
                                                event_warm_up_ready, event_initial_plot_ready, queue_warm_up,
                                                event_yhat_ready,
                                                queue_yhat,
                                                queue_frames_2_plot), 
                                            loop)
# wait for the task to finish
value = future.result()
# report a message
print(f'Got Async Result: {value}')
# Out:
# Asyncio event loop is running
# Waiting for capture thread
#
# $ Camera Thread: Is webcam open: True
# $ Camera Thread: Camera (width, height) = (640.0, 480.0) - FPS = 20.0
#
# $ Camera Thread: Warm up of 5 frames finished
# :):):) Plot Thread: start Initial Plot.
#
#
# $ Camera Thread: Waiting for Initial Plot
# HBox(children=(Button(button_style='danger', description='Stop', style=ButtonStyle()), HBox(children=(Label(va…
# HBox(children=(Button(button_style='danger', description='Stop', style=ButtonStyle()), HBox(children=(Label(va…
# VBox(children=(HTML(value='<center>UAV</center>'), Canvas()), layout=Layout(border='1.5px solid', width='fit-c…
# $ Camera Thread: Initial Plot finished
#
# ... Accel elapsed time: 848.84 [ms]
#
# Batch idx = 1
# --- Accel between predictions: 1.17 [secs]
# *** Mean Accel between predictions: 1.17 [secs]
# ... Accel elapsed time: 846.62 [ms]
#
# Batch idx = 2
# --- Accel between predictions: 0.93 [secs]
# *** Mean Accel between predictions: 1.05 [secs]
# ... Accel elapsed time: 829.82 [ms]
#
# Batch idx = 3
# --- Accel between predictions: 0.98 [secs]
# *** Mean Accel between predictions: 1.03 [secs]
# ... Accel elapsed time: 835.63 [ms]
#
# Batch idx = 4
# --- Accel between predictions: 0.99 [secs]
# *** Mean Accel between predictions: 1.02 [secs]
# ... Accel elapsed time: 834.53 [ms]
#
# Batch idx = 5
# --- Accel between predictions: 1.00 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 830.18 [ms]
#
# Batch idx = 6
# --- Accel between predictions: 1.04 [secs]
# *** Mean Accel between predictions: 1.02 [secs]
# ... Accel elapsed time: 828.57 [ms]
#
# Batch idx = 7
# --- Accel between predictions: 1.02 [secs]
# *** Mean Accel between predictions: 1.02 [secs]
# ... Accel elapsed time: 827.38 [ms]
#
# Batch idx = 8
# --- Accel between predictions: 0.97 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 827.22 [ms]
#
# Batch idx = 9
# --- Accel between predictions: 0.99 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 830.64 [ms]
#
# Batch idx = 10
# --- Accel between predictions: 1.19 [secs]
# *** Mean Accel between predictions: 1.03 [secs]
# ... Accel elapsed time: 824.09 [ms]
#
# Batch idx = 11
# --- Accel between predictions: 0.89 [secs]
# *** Mean Accel between predictions: 1.02 [secs]
# ... Accel elapsed time: 829.95 [ms]
#
# Batch idx = 12
# --- Accel between predictions: 0.92 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 832.80 [ms]
#
# Batch idx = 13
# --- Accel between predictions: 1.02 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 823.21 [ms]
#
# Batch idx = 14
# --- Accel between predictions: 1.01 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 826.96 [ms]
#
# Batch idx = 15
# --- Accel between predictions: 1.07 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 836.01 [ms]
#
# Batch idx = 16
# --- Accel between predictions: 0.91 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 822.84 [ms]
#
# Batch idx = 17
# --- Accel between predictions: 1.14 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 844.62 [ms]
#
# Batch idx = 18
# --- Accel between predictions: 0.90 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 832.50 [ms]
#
# Batch idx = 19
# --- Accel between predictions: 1.00 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 826.52 [ms]
#
# Batch idx = 20
# --- Accel between predictions: 1.08 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 822.64 [ms]
#
# Batch idx = 21
# --- Accel between predictions: 0.90 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 849.94 [ms]
#
# Batch idx = 22
# --- Accel between predictions: 1.10 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 850.49 [ms]
#
# Batch idx = 23
# --- Accel between predictions: 1.03 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 836.14 [ms]
#
# Batch idx = 24
# --- Accel between predictions: 0.89 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 824.91 [ms]
#
# Batch idx = 25
# --- Accel between predictions: 1.06 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 826.96 [ms]
#
# Batch idx = 26
# --- Accel between predictions: 0.95 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 831.15 [ms]
#
# Batch idx = 27
# --- Accel between predictions: 1.11 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 825.30 [ms]
#
# Batch idx = 28
# --- Accel between predictions: 0.89 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 838.72 [ms]
#
# Batch idx = 29
# --- Accel between predictions: 1.14 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 827.48 [ms]
#
# Batch idx = 30
# --- Accel between predictions: 0.89 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 827.97 [ms]
#
# Batch idx = 31
# --- Accel between predictions: 1.11 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 821.97 [ms]
#
# Batch idx = 32
# --- Accel between predictions: 0.87 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 834.25 [ms]
#
# Batch idx = 33
# --- Accel between predictions: 1.04 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 825.85 [ms]
#
# Batch idx = 34
# --- Accel between predictions: 0.87 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 645.76 [ms]
#
# Batch idx = 35
# --- Accel between predictions: 1.34 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 826.67 [ms]
#
# Batch idx = 36
# --- Accel between predictions: 0.90 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 830.62 [ms]
#
# Batch idx = 37
# --- Accel between predictions: 0.91 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 837.62 [ms]
#
# Batch idx = 38
# --- Accel between predictions: 1.03 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 830.42 [ms]
#
# Batch idx = 39
# --- Accel between predictions: 0.99 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 823.89 [ms]
#
# Batch idx = 40
# --- Accel between predictions: 1.03 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 829.76 [ms]
#
# Batch idx = 41
# --- Accel between predictions: 0.93 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 828.16 [ms]
#
# Batch idx = 42
# --- Accel between predictions: 1.10 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 822.41 [ms]
#
# Batch idx = 43
# --- Accel between predictions: 0.91 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 829.13 [ms]
#
# Batch idx = 44
# --- Accel between predictions: 0.84 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 626.39 [ms]
#
# Batch idx = 45
# --- Accel between predictions: 1.28 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 833.88 [ms]
#
# Batch idx = 46
# --- Accel between predictions: 0.72 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 636.01 [ms]
#
# Batch idx = 47
# --- Accel between predictions: 1.35 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 835.88 [ms]
#
# Batch idx = 48
# --- Accel between predictions: 0.94 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 841.01 [ms]
#
# Batch idx = 49
# --- Accel between predictions: 1.10 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 833.39 [ms]
#
# Batch idx = 50
# --- Accel between predictions: 0.89 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 827.63 [ms]
#
# Batch idx = 51
# --- Accel between predictions: 1.03 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 828.64 [ms]
#
# Batch idx = 52
# --- Accel between predictions: 1.00 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 825.89 [ms]
#
# Batch idx = 53
# --- Accel between predictions: 1.03 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 827.46 [ms]
#
# Batch idx = 54
# --- Accel between predictions: 0.96 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 843.15 [ms]
#
# Batch idx = 55
# --- Accel between predictions: 0.91 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 825.83 [ms]
#
# Batch idx = 56
# --- Accel between predictions: 1.18 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 834.41 [ms]
#
# Batch idx = 57
# --- Accel between predictions: 0.89 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 853.72 [ms]
#
# Batch idx = 58
# --- Accel between predictions: 1.19 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 824.52 [ms]
#
# Batch idx = 59
# --- Accel between predictions: 0.87 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 828.72 [ms]
#
# Batch idx = 60
# --- Accel between predictions: 1.02 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 854.74 [ms]
#
# Batch idx = 61
# --- Accel between predictions: 0.94 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 827.21 [ms]
#
# Batch idx = 62
# --- Accel between predictions: 0.97 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 831.15 [ms]
#
# Batch idx = 63
# --- Accel between predictions: 1.07 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 824.14 [ms]
#
# Batch idx = 64
# --- Accel between predictions: 0.94 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 826.38 [ms]
#
# Batch idx = 65
# --- Accel between predictions: 0.84 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 627.88 [ms]
#
# Batch idx = 66
# --- Accel between predictions: 1.29 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 834.51 [ms]
#
# Batch idx = 67
# --- Accel between predictions: 0.88 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 824.47 [ms]
#
# Batch idx = 68
# --- Accel between predictions: 1.08 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 827.16 [ms]
#
# Batch idx = 69
# --- Accel between predictions: 1.06 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 829.40 [ms]
#
# Batch idx = 70
# --- Accel between predictions: 0.70 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 637.65 [ms]
#
# Batch idx = 71
# --- Accel between predictions: 1.41 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 824.87 [ms]
#
# Batch idx = 72
# --- Accel between predictions: 0.71 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 626.28 [ms]
#
# Batch idx = 73
# --- Accel between predictions: 1.25 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 850.92 [ms]
#
# Batch idx = 74
# --- Accel between predictions: 0.87 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 829.89 [ms]
#
# Batch idx = 75
# --- Accel between predictions: 1.05 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 843.41 [ms]
#
# Batch idx = 76
# --- Accel between predictions: 0.99 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 825.03 [ms]
#
# Batch idx = 77
# --- Accel between predictions: 1.06 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 843.90 [ms]
#
# Batch idx = 78
# --- Accel between predictions: 0.88 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 829.84 [ms]
#
# Batch idx = 79
# --- Accel between predictions: 1.12 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 828.12 [ms]
#
# Batch idx = 80
# --- Accel between predictions: 0.88 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 824.41 [ms]
#
# Batch idx = 81
# --- Accel between predictions: 1.14 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 832.40 [ms]
#
# Batch idx = 82
# --- Accel between predictions: 0.96 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 849.10 [ms]
#
# Batch idx = 83
# --- Accel between predictions: 1.11 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 823.34 [ms]
#
# Batch idx = 84
# --- Accel between predictions: 0.94 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 838.37 [ms]
#
# Batch idx = 85
# --- Accel between predictions: 0.89 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 836.08 [ms]
#
# Batch idx = 86
# --- Accel between predictions: 1.02 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 833.12 [ms]
#
# Batch idx = 87
# --- Accel between predictions: 0.89 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 636.25 [ms]
#
# Batch idx = 88
# --- Accel between predictions: 1.20 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 832.82 [ms]
#
# Batch idx = 89
# --- Accel between predictions: 0.87 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 838.46 [ms]
#
# Batch idx = 90
# --- Accel between predictions: 1.08 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 828.09 [ms]
#
# Batch idx = 91
# --- Accel between predictions: 0.74 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 654.98 [ms]
#
# Batch idx = 92
# --- Accel between predictions: 1.28 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 827.53 [ms]
#
# Batch idx = 93
# --- Accel between predictions: 0.94 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 826.50 [ms]
#
# Batch idx = 94
# --- Accel between predictions: 1.05 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 840.43 [ms]
#
# Batch idx = 95
# --- Accel between predictions: 1.16 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 821.96 [ms]
#
# Batch idx = 96
# --- Accel between predictions: 0.89 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 826.15 [ms]
#
# Batch idx = 97
# --- Accel between predictions: 0.90 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 829.86 [ms]
#
# Batch idx = 98
# --- Accel between predictions: 1.04 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 832.90 [ms]
#
# Batch idx = 99
# --- Accel between predictions: 0.76 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 634.19 [ms]
#
# Batch idx = 100
# --- Accel between predictions: 1.28 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 831.83 [ms]
#
# Batch idx = 101
# --- Accel between predictions: 0.90 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 829.17 [ms]
#
# Batch idx = 102
# --- Accel between predictions: 1.11 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 830.23 [ms]
#
# Batch idx = 103
# --- Accel between predictions: 0.86 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 828.93 [ms]
#
# Batch idx = 104
# --- Accel between predictions: 1.13 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 835.50 [ms]
#
# Batch idx = 105
# --- Accel between predictions: 0.87 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 827.51 [ms]
#
# Batch idx = 106
# --- Accel between predictions: 1.14 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 848.12 [ms]
#
# Batch idx = 107
# --- Accel between predictions: 0.96 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 845.89 [ms]
#
# Batch idx = 108
# --- Accel between predictions: 1.05 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 828.02 [ms]
#
# Batch idx = 109
# --- Accel between predictions: 0.87 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 840.26 [ms]
#
# Batch idx = 110
# --- Accel between predictions: 1.09 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 836.59 [ms]
#
# Batch idx = 111
# --- Accel between predictions: 0.91 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 833.60 [ms]
#
# Batch idx = 112
# --- Accel between predictions: 1.08 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 826.97 [ms]
#
# Batch idx = 113
# --- Accel between predictions: 0.76 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 636.68 [ms]
#
# Batch idx = 114
# --- Accel between predictions: 1.25 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 833.41 [ms]
#
# Batch idx = 115
# --- Accel between predictions: 0.92 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 831.96 [ms]
#
# Batch idx = 116
# --- Accel between predictions: 1.08 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 827.54 [ms]
#
# Batch idx = 117
# --- Accel between predictions: 0.90 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 830.16 [ms]
#
# Batch idx = 118
# --- Accel between predictions: 1.03 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 831.22 [ms]
#
# Batch idx = 119
# --- Accel between predictions: 1.05 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 861.83 [ms]
#
# Batch idx = 120
# --- Accel between predictions: 1.08 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 824.06 [ms]
#
# Batch idx = 121
# --- Accel between predictions: 0.92 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 823.13 [ms]
#
# Batch idx = 122
# --- Accel between predictions: 1.03 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 830.55 [ms]
#
# Batch idx = 123
# --- Accel between predictions: 0.97 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 837.35 [ms]
#
# Batch idx = 124
# --- Accel between predictions: 1.03 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 831.77 [ms]
#
# Batch idx = 125
# --- Accel between predictions: 0.81 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 620.75 [ms]
#
# Batch idx = 126
# --- Accel between predictions: 1.22 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 824.77 [ms]
#
# Batch idx = 127
# --- Accel between predictions: 0.90 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 824.24 [ms]
#
# Batch idx = 128
# --- Accel between predictions: 1.13 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 829.50 [ms]
#
# Batch idx = 129
# --- Accel between predictions: 0.92 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 844.99 [ms]
#
# Batch idx = 130
# --- Accel between predictions: 1.14 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 840.89 [ms]
#
# Batch idx = 131
# --- Accel between predictions: 0.89 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 838.61 [ms]
#
# Batch idx = 132
# --- Accel between predictions: 1.23 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 840.71 [ms]
#
# Batch idx = 133
# --- Accel between predictions: 0.88 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 822.35 [ms]
#
# Batch idx = 134
# --- Accel between predictions: 0.89 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 841.17 [ms]
#
# Batch idx = 135
# --- Accel between predictions: 1.00 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 846.74 [ms]
#
# Batch idx = 136
# --- Accel between predictions: 1.03 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 834.85 [ms]
#
# Batch idx = 137
# --- Accel between predictions: 0.71 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 631.06 [ms]
#
# Batch idx = 138
# --- Accel between predictions: 1.28 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 830.90 [ms]
#
# Batch idx = 139
# --- Accel between predictions: 0.97 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 831.80 [ms]
#
# Batch idx = 140
# --- Accel between predictions: 1.01 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 833.15 [ms]
#
# Batch idx = 141
# --- Accel between predictions: 0.93 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 823.91 [ms]
#
# Batch idx = 142
# --- Accel between predictions: 1.11 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 824.00 [ms]
#
# Batch idx = 143
# --- Accel between predictions: 0.90 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 822.47 [ms]
#
# Batch idx = 144
# --- Accel between predictions: 1.16 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 836.99 [ms]
#
# Batch idx = 145
# --- Accel between predictions: 0.71 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 623.50 [ms]
#
# Batch idx = 146
# --- Accel between predictions: 1.32 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 840.56 [ms]
#
# Batch idx = 147
# --- Accel between predictions: 0.94 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 827.49 [ms]
#
# Batch idx = 148
# --- Accel between predictions: 0.98 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 829.11 [ms]
#
# Batch idx = 149
# --- Accel between predictions: 0.99 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 843.51 [ms]
#
# Batch idx = 150
# --- Accel between predictions: 1.12 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 825.27 [ms]
#
# Batch idx = 151
# --- Accel between predictions: 0.89 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 850.98 [ms]
#
# Batch idx = 152
# --- Accel between predictions: 0.87 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 632.76 [ms]
#
# Batch idx = 153
# --- Accel between predictions: 1.18 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 830.76 [ms]
#
# Batch idx = 154
# --- Accel between predictions: 0.93 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 838.92 [ms]
#
# Batch idx = 155
# --- Accel between predictions: 1.09 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 839.39 [ms]
#
# Batch idx = 156
# --- Accel between predictions: 0.88 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 825.18 [ms]
#
# Batch idx = 157
# --- Accel between predictions: 1.24 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 838.53 [ms]
#
# Batch idx = 158
# --- Accel between predictions: 0.86 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 821.94 [ms]
#
# Batch idx = 159
# --- Accel between predictions: 0.92 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 840.30 [ms]
#
# Batch idx = 160
# --- Accel between predictions: 1.09 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 826.96 [ms]
#
# Batch idx = 161
# --- Accel between predictions: 0.93 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 840.13 [ms]
#
# Batch idx = 162
# --- Accel between predictions: 1.01 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 831.67 [ms]
#
# Batch idx = 163
# --- Accel between predictions: 0.97 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 826.35 [ms]
#
# Batch idx = 164
# --- Accel between predictions: 1.07 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 824.91 [ms]
#
# Batch idx = 165
# --- Accel between predictions: 1.10 [secs]
# *** Mean Accel between predictions: 1.00 [secs]
# ... Accel elapsed time: 823.57 [ms]
#
# Batch idx = 166
# --- Accel between predictions: 1.25 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 824.45 [ms]
#
# Batch idx = 167
# --- Accel between predictions: 1.26 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 824.47 [ms]
#
# Batch idx = 168
# --- Accel between predictions: 0.94 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 839.55 [ms]
#
# Batch idx = 169
# --- Accel between predictions: 1.21 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 833.59 [ms]
#
# Batch idx = 170
# --- Accel between predictions: 0.73 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 626.17 [ms]
#
# Batch idx = 171
# --- Accel between predictions: 1.17 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 827.66 [ms]
#
# Batch idx = 172
# --- Accel between predictions: 0.87 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 829.43 [ms]
#
# Batch idx = 173
# --- Accel between predictions: 1.05 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 832.26 [ms]
#
# Batch idx = 174
# --- Accel between predictions: 1.00 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 829.78 [ms]
#
# Batch idx = 175
# --- Accel between predictions: 0.80 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 622.61 [ms]
#
# Batch idx = 176
# --- Accel between predictions: 1.25 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 833.30 [ms]
#
# Batch idx = 177
# --- Accel between predictions: 0.93 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 824.67 [ms]
#
# Batch idx = 178
# --- Accel between predictions: 1.08 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 833.94 [ms]
#
# Batch idx = 179
# --- Accel between predictions: 0.92 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 842.36 [ms]
#
# Batch idx = 180
# --- Accel between predictions: 1.01 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 837.14 [ms]
#
# Batch idx = 181
# --- Accel between predictions: 1.04 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 823.34 [ms]
#
# Batch idx = 182
# --- Accel between predictions: 1.02 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 823.87 [ms]
#
# Batch idx = 183
# --- Accel between predictions: 0.87 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 823.18 [ms]
#
# Batch idx = 184
# --- Accel between predictions: 1.12 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 822.41 [ms]
#
# Batch idx = 185
# --- Accel between predictions: 0.93 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 831.12 [ms]
#
# Batch idx = 186
# --- Accel between predictions: 1.05 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 828.96 [ms]
#
# Batch idx = 187
# --- Accel between predictions: 1.01 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 823.47 [ms]
#
# Batch idx = 188
# --- Accel between predictions: 0.95 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 840.20 [ms]
#
# Batch idx = 189
# --- Accel between predictions: 1.22 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 825.76 [ms]
#
# Batch idx = 190
# --- Accel between predictions: 0.88 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 834.07 [ms]
#
# Batch idx = 191
# --- Accel between predictions: 0.89 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 822.80 [ms]
#
# Batch idx = 192
# --- Accel between predictions: 1.09 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 841.32 [ms]
#
# Batch idx = 193
# --- Accel between predictions: 0.98 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 832.07 [ms]
#
# Batch idx = 194
# --- Accel between predictions: 1.03 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 831.70 [ms]
#
# Batch idx = 195
# --- Accel between predictions: 1.00 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 827.76 [ms]
#
# Batch idx = 196
# --- Accel between predictions: 1.01 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 823.61 [ms]
#
# Batch idx = 197
# --- Accel between predictions: 0.95 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 837.57 [ms]
#
# Batch idx = 198
# --- Accel between predictions: 1.03 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 844.73 [ms]
#
# Batch idx = 199
# --- Accel between predictions: 1.07 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 835.79 [ms]
#
# Batch idx = 200
# --- Accel between predictions: 0.90 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 827.40 [ms]
#
# Batch idx = 201
# --- Accel between predictions: 1.05 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 830.26 [ms]
#
# Batch idx = 202
# --- Accel between predictions: 1.01 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 821.82 [ms]
#
# Batch idx = 203
# --- Accel between predictions: 0.99 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 834.98 [ms]
#
# Batch idx = 204
# --- Accel between predictions: 1.01 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 858.87 [ms]
#
# Batch idx = 205
# --- Accel between predictions: 1.49 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 632.81 [ms]
#
# Batch idx = 206
# --- Accel between predictions: 1.48 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 829.69 [ms]
#
# Batch idx = 207
# --- Accel between predictions: 0.91 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 840.16 [ms]
#
# Batch idx = 208
# --- Accel between predictions: 0.91 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 839.99 [ms]
#
# Batch idx = 209
# --- Accel between predictions: 0.71 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 638.77 [ms]
#
# Batch idx = 210
# --- Accel between predictions: 1.18 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 825.50 [ms]
#
# Batch idx = 211
# --- Accel between predictions: 0.87 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 824.49 [ms]
#
# Batch idx = 212
# --- Accel between predictions: 0.88 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 827.32 [ms]
#
# Batch idx = 213
# --- Accel between predictions: 0.96 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 832.23 [ms]
#
# Batch idx = 214
# --- Accel between predictions: 1.08 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 821.21 [ms]
#
# Batch idx = 215
# --- Accel between predictions: 0.92 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 845.09 [ms]
#
# Batch idx = 216
# --- Accel between predictions: 1.02 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 837.38 [ms]
#
# Batch idx = 217
# --- Accel between predictions: 1.09 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 833.12 [ms]
#
# Batch idx = 218
# --- Accel between predictions: 0.95 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 841.65 [ms]
#
# Batch idx = 219
# --- Accel between predictions: 1.05 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 824.98 [ms]
#
# Batch idx = 220
# --- Accel between predictions: 0.94 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 840.12 [ms]
#
# Batch idx = 221
# --- Accel between predictions: 1.02 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 841.28 [ms]
#
# Batch idx = 222
# --- Accel between predictions: 1.00 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 839.20 [ms]
#
# Batch idx = 223
# --- Accel between predictions: 1.02 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 822.37 [ms]
#
# Batch idx = 224
# --- Accel between predictions: 0.97 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 827.46 [ms]
#
# Batch idx = 225
# --- Accel between predictions: 0.99 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 833.08 [ms]
#
# Batch idx = 226
# --- Accel between predictions: 0.97 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 831.38 [ms]
#
# Batch idx = 227
# --- Accel between predictions: 1.06 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 830.91 [ms]
#
# Batch idx = 228
# --- Accel between predictions: 1.02 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 824.42 [ms]
#
# Batch idx = 229
# --- Accel between predictions: 0.93 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 835.84 [ms]
#
# Batch idx = 230
# --- Accel between predictions: 1.24 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 824.71 [ms]
#
# Batch idx = 231
# --- Accel between predictions: 0.90 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 825.25 [ms]
#
# Batch idx = 232
# --- Accel between predictions: 0.86 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 824.43 [ms]
#
# Batch idx = 233
# --- Accel between predictions: 1.15 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 821.90 [ms]
#
# Batch idx = 234
# --- Accel between predictions: 0.87 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 833.75 [ms]
#
# Batch idx = 235
# --- Accel between predictions: 1.03 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 830.13 [ms]
#
# Batch idx = 236
# --- Accel between predictions: 1.00 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 838.32 [ms]
#
# Batch idx = 237
# --- Accel between predictions: 0.96 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 840.44 [ms]
#
# Batch idx = 238
# --- Accel between predictions: 1.15 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 829.93 [ms]
#
# Batch idx = 239
# --- Accel between predictions: 0.94 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 831.74 [ms]
#
# Batch idx = 240
# --- Accel between predictions: 0.78 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 626.81 [ms]
#
# Batch idx = 241
# --- Accel between predictions: 1.26 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 821.45 [ms]
#
# Batch idx = 242
# --- Accel between predictions: 1.06 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 833.90 [ms]
#
# Batch idx = 243
# --- Accel between predictions: 0.88 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 829.27 [ms]
#
# Batch idx = 244
# --- Accel between predictions: 0.99 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 830.59 [ms]
#
# Batch idx = 245
# --- Accel between predictions: 0.99 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 824.72 [ms]
#
# Batch idx = 246
# --- Accel between predictions: 1.01 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 837.66 [ms]
#
# Batch idx = 247
# --- Accel between predictions: 0.97 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 824.05 [ms]
#
# Batch idx = 248
# --- Accel between predictions: 0.84 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 632.19 [ms]
#
# Batch idx = 249
# --- Accel between predictions: 1.29 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 836.58 [ms]
#
# Batch idx = 250
# --- Accel between predictions: 0.69 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 659.87 [ms]
#
# Batch idx = 251
# --- Accel between predictions: 1.29 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 823.44 [ms]
#
# Batch idx = 252
# --- Accel between predictions: 0.86 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 827.95 [ms]
#
# Batch idx = 253
# --- Accel between predictions: 1.13 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 820.59 [ms]
#
# Batch idx = 254
# --- Accel between predictions: 0.92 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 839.09 [ms]
#
# Batch idx = 255
# --- Accel between predictions: 1.11 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 821.92 [ms]
#
# Batch idx = 256
# --- Accel between predictions: 0.92 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 854.61 [ms]
#
# Batch idx = 257
# --- Accel between predictions: 0.83 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 624.85 [ms]
#
# Batch idx = 258
# --- Accel between predictions: 1.25 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 848.09 [ms]
#
# Batch idx = 259
# --- Accel between predictions: 0.71 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 628.54 [ms]
#
# Batch idx = 260
# --- Accel between predictions: 1.24 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 830.07 [ms]
#
# Batch idx = 261
# --- Accel between predictions: 0.86 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 826.77 [ms]
#
# Batch idx = 262
# --- Accel between predictions: 1.16 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 828.27 [ms]
#
# Batch idx = 263
# --- Accel between predictions: 0.70 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 623.25 [ms]
#
# Batch idx = 264
# --- Accel between predictions: 1.27 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 824.92 [ms]
#
# Batch idx = 265
# --- Accel between predictions: 0.92 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 826.70 [ms]
#
# Batch idx = 266
# --- Accel between predictions: 1.06 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 826.36 [ms]
#
# Batch idx = 267
# --- Accel between predictions: 0.94 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 839.29 [ms]
#
# Batch idx = 268
# --- Accel between predictions: 1.49 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 828.85 [ms]
#
# Batch idx = 269
# --- Accel between predictions: 0.91 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 827.77 [ms]
#
# Batch idx = 270
# --- Accel between predictions: 0.99 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 834.12 [ms]
#
# Batch idx = 271
# --- Accel between predictions: 1.01 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 834.25 [ms]
#
# Batch idx = 272
# --- Accel between predictions: 1.00 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 826.34 [ms]
#
# Batch idx = 273
# --- Accel between predictions: 0.91 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 823.39 [ms]
#
# Batch idx = 274
# --- Accel between predictions: 1.18 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 833.86 [ms]
#
# Batch idx = 275
# --- Accel between predictions: 0.91 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 836.83 [ms]
#
# Batch idx = 276
# --- Accel between predictions: 0.98 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 828.50 [ms]
#
# Batch idx = 277
# --- Accel between predictions: 1.03 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 834.52 [ms]
#
# Batch idx = 278
# --- Accel between predictions: 0.92 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 826.07 [ms]
#
# Batch idx = 279
# --- Accel between predictions: 1.14 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 842.12 [ms]
#
# Batch idx = 280
# --- Accel between predictions: 0.99 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 824.65 [ms]
#
# Batch idx = 281
# --- Accel between predictions: 0.93 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 827.11 [ms]
#
# Batch idx = 282
# --- Accel between predictions: 1.05 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 827.62 [ms]
#
# Batch idx = 283
# --- Accel between predictions: 1.02 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 826.17 [ms]
#
# Batch idx = 284
# --- Accel between predictions: 0.94 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 836.87 [ms]
#
# Batch idx = 285
# --- Accel between predictions: 1.04 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 825.11 [ms]
#
# Batch idx = 286
# --- Accel between predictions: 0.99 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 823.80 [ms]
#
# Batch idx = 287
# --- Accel between predictions: 1.03 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 830.44 [ms]
#
# Batch idx = 288
# --- Accel between predictions: 1.01 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 829.43 [ms]
#
# Batch idx = 289
# --- Accel between predictions: 0.91 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 822.86 [ms]
#
# Batch idx = 290
# --- Accel between predictions: 1.18 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 824.46 [ms]
#
# Batch idx = 291
# --- Accel between predictions: 0.90 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 834.81 [ms]
#
# Batch idx = 292
# --- Accel between predictions: 0.99 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 835.95 [ms]
#
# Batch idx = 293
# --- Accel between predictions: 1.20 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 825.89 [ms]
#
# Batch idx = 294
# --- Accel between predictions: 0.90 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 833.11 [ms]
#
# Batch idx = 295
# --- Accel between predictions: 0.91 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 842.59 [ms]
#
# Batch idx = 296
# --- Accel between predictions: 0.95 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 836.46 [ms]
#
# Batch idx = 297
# --- Accel between predictions: 1.08 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 825.28 [ms]
#
# Batch idx = 298
# --- Accel between predictions: 0.98 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 822.10 [ms]
#
# Batch idx = 299
# --- Accel between predictions: 1.05 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 833.51 [ms]
#
# Batch idx = 300
# --- Accel between predictions: 0.90 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 831.14 [ms]
#
# Batch idx = 301
# --- Accel between predictions: 1.15 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 823.59 [ms]
#
# Batch idx = 302
# --- Accel between predictions: 0.86 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 823.84 [ms]
#
# Batch idx = 303
# --- Accel between predictions: 0.84 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 637.12 [ms]
#
# Batch idx = 304
# --- Accel between predictions: 1.24 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 829.00 [ms]
#
# Batch idx = 305
# --- Accel between predictions: 0.79 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 634.22 [ms]
#
# Batch idx = 306
# --- Accel between predictions: 1.31 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 825.36 [ms]
#
# Batch idx = 307
# --- Accel between predictions: 0.87 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 834.06 [ms]
#
# Batch idx = 308
# --- Accel between predictions: 1.19 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 832.74 [ms]
#
# Batch idx = 309
# --- Accel between predictions: 0.87 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 829.84 [ms]
#
# Batch idx = 310
# --- Accel between predictions: 0.90 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 830.16 [ms]
#
# Batch idx = 311
# --- Accel between predictions: 1.11 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 829.62 [ms]
#
# Batch idx = 312
# --- Accel between predictions: 0.90 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 825.92 [ms]
#
# Batch idx = 313
# --- Accel between predictions: 1.09 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 832.99 [ms]
#
# Batch idx = 314
# --- Accel between predictions: 0.86 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 821.75 [ms]
#
# Batch idx = 315
# --- Accel between predictions: 1.10 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 822.63 [ms]
#
# Batch idx = 316
# --- Accel between predictions: 0.97 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 834.89 [ms]
#
# Batch idx = 317
# --- Accel between predictions: 1.00 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 830.51 [ms]
#
# Batch idx = 318
# --- Accel between predictions: 1.02 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 841.05 [ms]
#
# Batch idx = 319
# --- Accel between predictions: 1.14 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 823.71 [ms]
#
# Batch idx = 320
# --- Accel between predictions: 0.88 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 823.36 [ms]
#
# Batch idx = 321
# --- Accel between predictions: 0.91 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 825.14 [ms]
#
# Batch idx = 322
# --- Accel between predictions: 1.16 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 823.14 [ms]
#
# Batch idx = 323
# --- Accel between predictions: 0.90 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 847.77 [ms]
#
# Batch idx = 324
# --- Accel between predictions: 0.91 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 825.63 [ms]
#
# Batch idx = 325
# --- Accel between predictions: 1.10 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 831.39 [ms]
#
# Batch idx = 326
# --- Accel between predictions: 1.04 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 825.82 [ms]
#
# Batch idx = 327
# --- Accel between predictions: 1.00 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 832.78 [ms]
#
# Batch idx = 328
# --- Accel between predictions: 0.95 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 825.41 [ms]
#
# Batch idx = 329
# --- Accel between predictions: 1.02 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 838.00 [ms]
#
# Batch idx = 330
# --- Accel between predictions: 1.05 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 834.96 [ms]
#
# Batch idx = 331
# --- Accel between predictions: 0.89 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 838.91 [ms]
#
# Batch idx = 332
# --- Accel between predictions: 1.19 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 823.21 [ms]
#
# Batch idx = 333
# --- Accel between predictions: 0.87 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 829.01 [ms]
#
# Batch idx = 334
# --- Accel between predictions: 0.95 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 827.59 [ms]
#
# Batch idx = 335
# --- Accel between predictions: 1.11 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 822.80 [ms]
#
# Batch idx = 336
# --- Accel between predictions: 0.89 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 825.96 [ms]
#
# Batch idx = 337
# --- Accel between predictions: 0.90 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 627.37 [ms]
#
# Batch idx = 338
# --- Accel between predictions: 1.18 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 838.30 [ms]
#
# Batch idx = 339
# --- Accel between predictions: 0.89 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 823.67 [ms]
#
# Batch idx = 340
# --- Accel between predictions: 1.14 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 836.02 [ms]
#
# Batch idx = 341
# --- Accel between predictions: 0.92 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 832.37 [ms]
#
# Batch idx = 342
# --- Accel between predictions: 0.89 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 639.29 [ms]
#
# Batch idx = 343
# --- Accel between predictions: 1.16 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 826.19 [ms]
#
# Batch idx = 344
# --- Accel between predictions: 1.07 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 831.04 [ms]
#
# Batch idx = 345
# --- Accel between predictions: 1.79 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 863.42 [ms]
#
# Batch idx = 346
# --- Accel between predictions: 1.32 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 664.72 [ms]
#
# Batch idx = 347
# --- Accel between predictions: 1.70 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 856.50 [ms]
#
# Batch idx = 348
# --- Accel between predictions: 1.53 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 848.86 [ms]
# KeyboardInterrupt
# Batch idx = 349
# --- Accel between predictions: 1.34 [secs]
# *** Mean Accel between predictions: 1.01 [secs]
# ... Accel elapsed time: 708.41 [ms]
# HBox(children=(Button(button_style='danger', description='Stop', style=ButtonStyle()), HBox(children=(Label(va…

# %% [markdown]
# ### Wait for Threads

# %%
# cap_thread.join()
# batches_thread.join()
# accel_thread.join()

# %% [markdown]
# # Main Thread Loop

# %% [markdown]
# ### Plot inside Asyncio Loop Thread

# %%
# plot_thread.join()
    
end_running = datetime.now()

print(f'\nElapsed time = {end_running - start_running}.')

# %% [markdown]
# ### Plot in Main Thread

# %%
# '''
# When yhat is ready, it retrives a frame from Queue Frames to Plot and yhat from Queue Yhat.
# Calculates the mean of yhat for both classes and plot it.
# '''

# plot_batch_idx = 0

# while True:
#     event_yhat_ready.wait()
#     event_yhat_ready.clear()
#     yhat_batch_idx, yhat = queue_yhat.get()
#     plot_frames_idx, frame_to_plot = queue_frames_2_plot.get()
#     assert yhat_batch_idx == plot_batch_idx, f':) Main Thread: plot batch idx {plot_batch_idx} does not match yhat batch idx {yhat_batch_idx}.'
#     assert plot_frames_idx == plot_batch_idx, f':) Main Thread: plot frames idx {plot_frames_idx} does not match batch idx {yhat_batch_idx}.'
#     if yhat is None:
#         print(':):):) Main Thread: yhat is None received -> Execution Finished')
#         break
#     else:
#         smoke_mean = np.mean(yhat[:, 0])
#         fire_mean = np.mean(yhat[:, 1])
#         if VERBOSE:
#             print(f':):):) Main Thread: yhat\n {yhat}')
#             print(f':):):) Main Thread: smoke mean = {smoke_mean}')
#             print(f':):):) Main Thread: fire mean = {fire_mean}')
#             # print(f':):):) Main Thread: yhat\n {type(yhat)}')
#             # print(f':):):) Main Thread: yhat\n {yhat.shape}')
#         jcv2.imshow('UAV', frame_to_plot)
#         if jcv2.waitKey(1)==ord('q'):
#             break 
#         plot_batch_idx += 1
#         queue_yhat.task_done()
#         queue_frames_2_plot.task_done()
        
# queue_yhat.task_done()
# queue_frames_2_plot.task_done()
# jcv2.destroyAllWindows()

# end_running = datetime.now()

# print(f'\nElapsed time = {end_running - start_running}.')
